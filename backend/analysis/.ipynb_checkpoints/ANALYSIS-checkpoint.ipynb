# %%
import numpy
from matplotlib import pyplot as plt, mlab
import scipy.io.wavfile
#import scipy.signal.spectrogram
from collections import defaultdict

# %% [markdown]
# Конвертировать mp3 в wav:

# %%
from pydub import AudioSegment

# %%
AWAV = "./rec_notes/a.wav"
SS_KATUSHA = "./rec_notes/katusha_long.wav"
SS_KATUSHA_U12 = "./rec_notes/katusha_+12.wav"

# %%
sound = AudioSegment.from_mp3("./rec_notes/a.mp3")
sound.export("./rec_notes/a.wav", format="wav")
# Out:
# <_io.BufferedRandom name='./rec_notes/a.wav'>

# %%
sound = AudioSegment.from_mp3("./rec_notes/katusha.mp3")
sound.export("./rec_notes/katusha.wav", format="wav")
# Out:
# <_io.BufferedRandom name='./rec_notes/katusha.wav'>

# %% [markdown]
# Рисуем спектрограмму:

# %%
SAMPLE_RATE = 44100 # Hz
WINDOW_SIZE = 4096 # размер окна, в котором делается fft
WINDOW_STEP = 512 # шаг окна

def get_wave_data(wave_filename):
    sample_rate, wave_data = scipy.io.wavfile.read(wave_filename)
    assert sample_rate == SAMPLE_RATE, sample_rate
    if isinstance(wave_data[0], numpy.ndarray): # стерео
        wave_data = wave_data.mean(1)
    return wave_data

def show_specgram(wave_data):
    plt.figure(figsize=(15, 9))
    fig = plt.figure(figsize=(15, 9))
    ax = fig.add_axes((0.1, 0.1, 0.8, 0.8))
    ax.specgram(wave_data,
        NFFT=WINDOW_SIZE, noverlap=WINDOW_SIZE - WINDOW_STEP, Fs=SAMPLE_RATE)
    plt.ylim((0, 2000))
    plt.xlim((10, 20цифровых сигналов))
    plt.show()

# %%
wave_data = get_wave_data(SS_KATUSHA)
show_specgram(wave_data)

# %%
wave_data = get_wave_data(SS_KATUSHA_U12)
show_specgram(wave_data)

# %%
wave_data = get_wave_data(AWAV)
show_specgram(wave_data)

# %%
scipy.signal.spectrogram(wave_data, )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-458e9f1fa56c> in <module>()
#       1 scipy.signal.spectrogram(wave_data,
# ----> 2         window=WINDOW_SIZE, fs=SAMPLE_RATE)
#
# /usr/local/lib/python3.4/dist-packages/scipy/signal/spectral.py in spectrogram(x, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, scaling, axis, mode)
#     547     # need to set default for nperseg before setting default for noverlap below
#     548     window, nperseg = _triage_segments(window, nperseg,
# --> 549                                        input_length=x.shape[axis])
#     550
#     551     # Less overlap than welch, so samples are more statisically independent
#
# /usr/local/lib/python3.4/dist-packages/scipy/signal/spectral.py in _triage_segments(window, nperseg, input_length)
#    1637         win = np.asarray(window)
# ...
